# %% [markdown]
# <a href="https://colab.research.google.com/github/raulbenitez/PRML_exploratory_analysis/blob/main/clustering_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
import seaborn as sns

iris = sns.load_dataset("iris")

X = iris[['sepal_length','sepal_width','petal_length','petal_width']] # features
y = iris['species'] # class labels

group = KMeans(n_clusters=3).fit_predict(X)

iris_grouped = iris
iris_grouped['kmeans'] = group
g = sns.pairplot(iris_grouped, hue="kmeans")
